# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/Updated_Dataset_Cleaned.csv')
df.iloc[:2,7:]
# Out:
#     Make    Model                   Electric Vehicle Type  \
# 0    BMW       X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 1  TESLA  MODEL 3          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility   Full Vehicle Name  \
# 0           Clean Alternative Fuel Vehicle Eligible         2021 BMW X5
# 1           Clean Alternative Fuel Vehicle Eligible  2018 TESLA MODEL 3
#
#    Fetched Range  Electric Range  Max Range  Fetched Price  Base MSRP  \
# 0              0            30.0       30.0          60000        0.0
# 1            322           215.0      322.0          35490        0.0
#
#    Legislative District  DOL Vehicle ID                 Vehicle Location  \
# 0                  35.0       267929112  POINT (-122.8728334 47.5798304)
# 1                  23.0       475911439  POINT (-122.6368884 47.7469547)
#
#          Electric Utility  2020 Census Tract
# 0  PUGET SOUND ENERGY INC       5.303509e+10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210165 entries, 0 to 210164
# Data columns (total 22 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   Unnamed: 0                                         210165 non-null  int64
#  1   VIN (1-10)                                         210165 non-null  object
#  2   County                                             210161 non-null  object
#  3   City                                               210161 non-null  object
#  4   State                                              210165 non-null  object
#  5   Postal Code                                        210161 non-null  float64
#  6   Model Year                                         210165 non-null  int64
#  7   Make                                               210165 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                             0
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Full Vehicle Name                                      0
# Fetched Range                                          0
# Electric Range                                         5
# Max Range                                              0
# Fetched Price                                          0
# ...

# %%
len(df[df['Max Range']==0])
# Out:
# 7777

# %%
len(df[df['Fetched Price']==0])
# Out:
# 0

# %%
# Drop rows where max range is 0
df.drop(df[df['Max Range']==0].index, inplace=True)
len(df[df['Max Range']==0])
# Out:
# 0

# %%
# Simplify the EV Type and CAFV cols
df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Not eligible due to low battery range',
#        'Eligibility unknown as battery range has not been researched'],
#       dtype=object)

# %%
df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] = df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].apply(lambda x: False if 'Not' in x \
                                                                                                                        else (False if 'unknown' in x else True))

# %%
print('Columns before:')
print(df.columns)
df.drop(['Unnamed: 0', 'VIN (1-10)', 'Fetched Range', 'Electric Range', 'Base MSRP', 'DOL Vehicle ID', 'Electric Utility', '2020 Census Tract'], inplace=True, axis=1)
print('Columns after:')
print(df.columns)
# Out:
# Columns before:
# Index(['Unnamed: 0', 'VIN (1-10)', 'County', 'City', 'State', 'Postal Code',
#        'Model Year', 'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility',
#        'Full Vehicle Name', 'Fetched Range', 'Electric Range', 'Max Range',
#        'Fetched Price', 'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')
# Columns after:
# Index(['County', 'City', 'State', 'Postal Code', 'Model Year', 'Make', 'Model',
#        'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility',
#        'Full Vehicle Name', 'Max Range', 'Fetched Price',
#        'Legislative District', 'Vehicle Location'],
#       dtype='object')

# %% [markdown]
# Data after initial cleaning

# %%
df.head()
# Out:
#       County       City State  Postal Code  Model Year     Make     Model  \
# 0     Kitsap    Seabeck    WA      98380.0        2021      BMW        X5
# 1     Kitsap    Poulsbo    WA      98370.0        2018    TESLA   MODEL 3
# 2  Snohomish    Bothell    WA      98012.0        2016  PORSCHE  PANAMERA
# 3     Kitsap  Bremerton    WA      98310.0        2018    TESLA   MODEL 3
# 4       King    Redmond    WA      98052.0        2019   NISSAN      LEAF
#
#                     Electric Vehicle Type  \
# 0  Plug-in Hybrid Electric Vehicle (PHEV)
# 1          Battery Electric Vehicle (BEV)
# 2  Plug-in Hybrid Electric Vehicle (PHEV)
# 3          Battery Electric Vehicle (BEV)
# 4          Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility      Full Vehicle Name  \
# 0                                               True            2021 BMW X5
# 1                                               True     2018 TESLA MODEL 3
# ...

# %%
df.to_csv('pre_processed_data.csv')
